# %%
import cv2
import matplotlib.pyplot as plt

# Read an image file
img = cv2.imread("src\docs\phantom images\T1.jpg")

contrast = int(input("Enter contrast value (0-255): "))
brightness = int(input("Enter brightness value (-255 to 255): "))

new_img = cv2.addWeighted(img, contrast/127, img, 0, brightness - 127)

plt.subplots(2,1,figsize=(15,15))
plt.subplot(2,1,1),plt.imshow(img, cmap='gray'),
plt.subplot(2,1,2),plt.imshow(new_img, cmap='gray')
# Out:
# (<AxesSubplot:>, <matplotlib.image.AxesImage at 0x17f5dc4ecd0>)
